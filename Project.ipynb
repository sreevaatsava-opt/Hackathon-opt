# %%
print("Objective: To calculate customer value by using past purchase data and key metrics to predict Customer Lifetime Value (CLV).")
# Out:
# Objective: To calculate customer value by using past purchase data and key metrics to predict Customer Lifetime Value (CLV).
